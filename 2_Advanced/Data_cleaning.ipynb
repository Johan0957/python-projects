# %%
import pandas as pd
import numpy as ny
import matplotlib as plt
from datasets import load_dataset
dataset=load_dataset('lukebarousse/data_jobs')
df=dataset['train'].to_pandas()
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(2), object(11)
# memory usage: 86.2+ MB

# %%
median_year_avg=df['salary_year_avg'].median()
median_hour_avg=df['salary_hour_avg'].median()

# %%
df_filled=df.copy()
df_filled['salary_hour_avg']=df_filled['salary_hour_avg'].fillna(median_hour_avg)
df_filled['salary_year_avg']=df_filled['salary_year_avg'].fillna(median_year_avg)

# %%
df_unique=df_filled.drop_duplicates(subset=['job_title','company_name'])
df_unique.loc[:]
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785735  Senior Data Engineer
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785735                               Senior Data Engineer
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785740                                 AWS System Analyst
#
#                         job_location                     job_via  \
# 0                      Watertown, CT             via Work Nearby
# 1       Guadalajara, Jalisco, Mexico            via BeBee México
# 2                    Berlin, Germany                via LinkedIn
# 3                    San Antonio, TX           via Diversity.com
# 4                     Washington, DC          via Clearance Jobs
# ...                              ...                         ...
# 785735                Berlin, Jerman  melalui Top County Careers
# 785736                     Singapura         melalui Trabajo.org
# 785737            Bad Rodach, Jerman   melalui BeBee Deutschland
# 785738                      Malaysia            melalui Ricebowl
# 785740                         India              melalui Trigyn
#
#        job_schedule_type  job_work_from_home       search_location  \
# 0              Full-time               False  Texas, United States
# 1              Full-time               False                Mexico
# 2              Full-time               False               Germany
# 3              Full-time               False  Texas, United States
# 4              Full-time               False                 Sudan
# ...                  ...                 ...                   ...
# 785735   Pekerjaan tetap               False               Germany
# 785736   Pekerjaan tetap               False             Singapore
# 785737   Pekerjaan tetap               False               Germany
# 785738   Pekerjaan tetap               False              Malaysia
# 785740   Pekerjaan tetap               False                 India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0      2023-06-16 13:44:15                  False                 False
# 1      2023-01-14 13:18:07                  False                 False
# 2      2023-10-10 13:14:55                  False                 False
# 3      2023-07-04 13:01:41                   True                 False
# 4      2023-08-07 14:29:36                  False                 False
# ...                    ...                    ...                   ...
# 785735 2023-03-13 06:19:07                  False                 False
# 785736 2023-03-13 06:16:16                  False                 False
# 785737 2023-03-12 06:18:18                  False                 False
# 785738 2023-03-12 06:32:36                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0       United States        None         115000.0            45.98
# 1              Mexico        None         115000.0            45.98
# 2             Germany        None         115000.0            45.98
# 3       United States        None         115000.0            45.98
# 4               Sudan        None         115000.0            45.98
# ...               ...         ...              ...              ...
# 785735        Germany        None         115000.0            45.98
# 785736      Singapore        None         115000.0            45.98
# 785737        Germany        None         115000.0            45.98
# 785738       Malaysia        None         115000.0            45.98
# 785740          India        None         115000.0            45.98
#
#                               company_name  \
# 0                     Boehringer Ingelheim
# 1               Hewlett Packard Enterprise
# 2                 ALPHA Augmented Services
# 3             Southwest Research Institute
# 4                          Kristina Daniel
# ...                                    ...
# 785735                            Pure App
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785740                              Trigyn
#
#                                                job_skills  \
# 0                                                    None
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 785735  ['sql', 'python', 'bigquery', 'aws', 'airflow'...
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 0                                                    None
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                   ...
# 785735  {'cloud': ['bigquery', 'aws'], 'libraries': ['...
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785740              {'cloud': ['aws'], 'other': ['flow']}
#
# [508042 rows x 17 columns]

# %%
df_unique.sample(10,random_state=42)
# Out:
#               job_title_short  \
# 213738  Senior Data Scientist
# 356513   Senior Data Engineer
# 581679           Data Analyst
# 649012          Data Engineer
# 171348           Data Analyst
# 73499           Data Engineer
# 758336       Business Analyst
# 137081         Data Scientist
# 564884           Data Analyst
# 16635       Software Engineer
#
#                                                 job_title  \
# 213738                               Data Management Lead
# 356513    Senior Lead Data Engineer - Energetic Workplace
# 581679                    Technical Data Analyst (Remote)
# 649012                           Junior SQL Data Engineer
# 171348                      Data Analyst Marketing Intern
# 73499   Data engineer - Hauts de France / Lille (59) H...
# 758336             Raintree Business Intelligence Analyst
# 137081                                  AI Data Scientist
# 564884                                     Data Analytics
# 16635                                   Software Engineer
#
#                                           job_location  \
# 213738               Taguig, Metro Manila, Philippines
# 356513           São Paulo, State of São Paulo, Brazil
# 581679                                        Anywhere
# 649012                                      London, UK
# 171348                                   Paris, France
# 73499                             La Madeleine, France
# 758336                                Jacksonville, FL
# 137081                                      London, UK
# 564884                                       Hong Kong
# 16635   Florence, Metropolitan City of Florence, Italy
#
#                        job_via job_schedule_type  job_work_from_home  \
# 213738         via Trabajo.org         Full-time               False
# 356513            via GrabJobs         Full-time               False
# 581679            via LinkedIn              None                True
# 649012           via WJHL Jobs         Full-time               False
# 171348               via BeBee        Internship               False
# 73499          via Recruit.net         Full-time               False
# 758336               via BeBee         Full-time               False
# 137081            via LinkedIn         Full-time               False
# 564884  via LinkedIn Hong Kong         Full-time               False
# 16635             via Linkedin         Full-time               False
#
#                search_location     job_posted_date  job_no_degree_mention  \
# 213738             Philippines 2023-07-12 22:17:54                  False
# 356513                  Brazil 2023-10-22 23:39:35                   True
# 581679             Philippines 2023-07-16 09:17:56                   True
# 649012          United Kingdom 2023-07-15 12:12:59                   True
# 171348                  France 2023-06-25 16:00:32                  False
# 73499                   France 2023-09-17 00:21:17                   True
# 758336  Florida, United States 2023-08-11 20:02:44                  False
# 137081          United Kingdom 2023-10-05 08:10:17                  False
# 564884               Hong Kong 2023-10-17 04:35:22                   True
# 16635                    Italy 2023-07-12 13:13:54                  False
#
#         job_health_insurance     job_country salary_rate  salary_year_avg  \
# 213738                 False     Philippines        None         115000.0
# 356513                 False          Brazil        None         115000.0
# 581679                 False     Philippines        None         115000.0
# 649012                 False  United Kingdom        None         115000.0
# 171348                 False          France        None         115000.0
# 73499                  False          France        None         115000.0
# 758336                  True   United States        None         115000.0
# 137081                 False  United Kingdom        None         115000.0
# 564884                 False       Hong Kong        None         115000.0
# 16635                  False           Italy        None         115000.0
#
#         salary_hour_avg                      company_name  \
# 213738            45.98                             Globe
# 356513            45.98  Ewave Do Brasil Informatica Ltda
# 581679            45.98                          MediaDev
# 649012            45.98                       Jobleads-UK
# 171348            45.98              Vestiaire Collective
# 73499             45.98                             OTTEO
# 758336            45.98                          H2Health
# 137081            45.98                      Anson McCade
# 564884            45.98                         NielsenIQ
# 16635             45.98                             Aidia
#
#                                                job_skills  \
# 213738                                               None
# 356513  ['sas', 'sas', 'sql', 'python', 'azure', 'data...
# 581679                                          ['excel']
# 649012                  ['sql', 't-sql', 'azure', 'ssis']
# 171348              ['sql', 'python', 'excel', 'tableau']
# 73499                   ['looker', 'github', 'terraform']
# 758336                                    ['sql', 'flow']
# 137081                                               None
# 564884                                               None
# 16635   ['python', 'java', 'shell', 'django', 'angular...
#
#                                           job_type_skills
# 213738                                               None
# 356513  {'analyst_tools': ['sas', 'power bi'], 'cloud'...
# 581679                       {'analyst_tools': ['excel']}
# 649012  {'analyst_tools': ['ssis'], 'cloud': ['azure']...
# 171348  {'analyst_tools': ['excel', 'tableau'], 'progr...
# 73499   {'analyst_tools': ['looker'], 'other': ['githu...
# 758336        {'other': ['flow'], 'programming': ['sql']}
# 137081                                               None
# 564884                                               None
# 16635   {'analyst_tools': ['power bi', 'tableau'], 'os...
